# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'output.xlsx')

# %%
df
# Out:
#                                    C                      1653596335929.pdf  \
# 0                           Training                      1660942895912.pdf
# 1                                Ibm                      1655328514623.pdf
# 2        54998637-Ahmed-Sobhi-CV.doc                                    NaN
# 3                           Training     547847274-CV-2021-10-08-094149.pdf
# 4                   518594192-cv.doc                                    NaN
# ..                               ...                                    ...
# 616                           Orange                  Digital marketing.pdf
# 617  82865930-MOHAMED-FAHMY-CV-1.doc                                    NaN
# 618                         Training                 487291217-CV-docx.docx
# 619                              Api                Mahmoud Mohamed CV .pdf
# 620                         Training  295307146-Cv-Ahmed-i-abdelsalam-1.pdf
#
# ...

# %%
file = df.iloc[:,1]

# %%
df.drop(['1653596335929.pdf'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (621, 83)

# %%
file.shape
# Out:
# (621,)

# %%
df = pd.concat([file,df], axis =1)

# %%
df
# Out:
#                          1653596335929.pdf                                C  \
# 0                        1660942895912.pdf                         Training
# 1                        1655328514623.pdf                              Ibm
# 2                                      NaN      54998637-Ahmed-Sobhi-CV.doc
# 3       547847274-CV-2021-10-08-094149.pdf                         Training
# 4                                      NaN                 518594192-cv.doc
# ..                                     ...                              ...
# 616                  Digital marketing.pdf                           Orange
# 617                                    NaN  82865930-MOHAMED-FAHMY-CV-1.doc
# 618                 487291217-CV-docx.docx                         Training
# 619                Mahmoud Mohamed CV .pdf                              Api
# 620  295307146-Cv-Ahmed-i-abdelsalam-1.pdf                         Training
#
# ...

# %%
df1= pd.DataFrame(df.iloc[:,0].values, columns=['File'])

# %%
df1
# Out:
#                                       File
# 0                        1660942895912.pdf
# 1                        1655328514623.pdf
# 2                                      NaN
# 3       547847274-CV-2021-10-08-094149.pdf
# 4                                      NaN
# ..                                     ...
# 616                  Digital marketing.pdf
# 617                                    NaN
# 618                 487291217-CV-docx.docx
# 619                Mahmoud Mohamed CV .pdf
# 620  295307146-Cv-Ahmed-i-abdelsalam-1.pdf
#
# [621 rows x 1 columns]

# %%
ls= []
for i in range(len(df)):
    tup = list(df.iloc[i,1:])
    ls.append(tup)
    
df1['skills'] = ls

# %%
df1
# Out:
#                                       File  \
# 0                        1660942895912.pdf
# 1                        1655328514623.pdf
# 2                                      NaN
# 3       547847274-CV-2021-10-08-094149.pdf
# 4                                      NaN
# ..                                     ...
# 616                  Digital marketing.pdf
# 617                                    NaN
# 618                 487291217-CV-docx.docx
# 619                Mahmoud Mohamed CV .pdf
# 620  295307146-Cv-Ahmed-i-abdelsalam-1.pdf
#
#                                                 skills
# 0    [Training, C, .net, Access, Communication, Mys...
# 1    [Ibm, Word, Scrum, Aws, Mysql, Programming, Sy...
# 2    [54998637-Ahmed-Sobhi-CV.doc, nan, nan, nan, n...
# 3    [Training, Microsoft excel, Word, Autocad, Con...
# 4    [518594192-cv.doc, nan, nan, nan, nan, nan, na...
# ..                                                 ...
# ...

# %%
ls=[]
k=[]
for i in range(len(df)):
    for j in df1.iloc[i,1]:
        if type(j)!=str and math.isnan(j):
            continue
        else:
            ls.append(j)
    k.append(ls)
    ls=[]

# %%
# sa=pd.Series([1,2])
f = pd. DataFrame([1,2], columns = ["skills"])
f['skills']=f['skills'].astype('object')
for i in range(len(k)):
    f.at[i,'skills']=k[i]

# %%
df1 = pd.concat([df1.iloc[:,:],f.iloc[:,:]], axis = 1)

# %%
idx = []
for j in range(len(df1)):
    if type(df1.iloc[j,0]) != str and math.isnan(df1.iloc[j,0]):
        idx.append(j)

# %%
len(idx)
# Out:
# 104

# %%
for i in idx:
    df1.drop(df.index[i], inplace=True)

# %%
df1.reset_index(inplace = True, drop = True)

# %%
df1.to_csv('file.csv')

# %%
g=df1.copy()
g
# Out:
#                                       File  \
# 0                        1660942895912.pdf
# 1                        1655328514623.pdf
# 2                                      NaN
# 3       547847274-CV-2021-10-08-094149.pdf
# 4                                      NaN
# ..                                     ...
# 616                  Digital marketing.pdf
# 617                                    NaN
# 618                 487291217-CV-docx.docx
# 619                Mahmoud Mohamed CV .pdf
# 620  295307146-Cv-Ahmed-i-abdelsalam-1.pdf
#
#                                                 skills
# 0    [Training, C, .net, Access, Communication, Mys...
# 1    [Ibm, Word, Scrum, Aws, Mysql, Programming, Sy...
# 2                        [54998637-Ahmed-Sobhi-CV.doc]
# 3    [Training, Microsoft excel, Word, Autocad, Con...
# 4                                   [518594192-cv.doc]
# ..                                                 ...
# ...

# %%
g
# Out:
#     ko             (0, 0)                  0
# 0  NaN           Training           Training
# 1  NaN                  C                  C
# 2  NaN               .net               .net
# 3  NaN             Access             Access
# 4  NaN      Communication      Communication
# 5  NaN              Mysql              Mysql
# 6  NaN        Programming        Programming
# 7  NaN             System             System
# 8  NaN         Postgresql         Postgresql
# 9  NaN                Xml                Xml
# 10 NaN  Operating systems  Operating systems
# 11 NaN              Email              Email
# 12 NaN          Scripting          Scripting
# 13 NaN             Github             Github
# 14 NaN             Visual             Visual
# 15 NaN              Linux              Linux
# 16 NaN             Design             Design
# 17 NaN                Try                Try
# 18 NaN         Javascript         Javascript
# 19 NaN               Json               Json
# ...
